# %%
import pandas as pd
Location = "C:/Users/VT_SA/Downloads/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
import numpy as np 
df['timemgmt'] = np.where((df['exercise']>3) & (df['hours']>17), 'Busy','Free')
df.tail(50)
# Out:
#           fname      lname  gender  age  exercise  hours  grade  \
# 1950     Kaseem      Finch    male   18         1     16   97.1
# 1951      Lydia       Cook  female   16         5      7   71.7
# 1952      Tatum       Hall  female   16         1      7   75.0
# 1953       Erin    Mercado  female   15         4      9   71.4
# 1954   Beatrice      Price  female   17         4     14   82.5
# 1955     Carlos     Ingram    male   16         5     17   98.7
# 1956       Neve     Barnes  female   19         2      9   79.8
# 1957     Aileen     Sutton  female   18         5     16   91.4
# 1958      Craig    Roberts    male   14         1      5   66.4
# 1959    Chelsea   Holloway  female   19         4     12   91.4
# 1960    Emerald   Mckinney  female   17         3      8   78.4
# 1961       Nero    Kennedy    male   14         4     14   88.3
# 1962     August      Green    male   16         2      9   87.2
# 1963    Colleen    Holland  female   18         1      5   70.2
# ...
